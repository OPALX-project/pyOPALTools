# %% [markdown]
# ## Load Dataset

# %%
from amr import AmrOpal

ao = AmrOpal()


ao.load_file(dirname='/home/matthias/Documents/projects/pyOPALTools/amr/tests/yt-testUnifSphere/',
             showme=False)
# Out:
# yt : [INFO     ] 2018-03-11 11:14:43,471 Parameters: current_time              = 0.0
# yt : [INFO     ] 2018-03-11 11:14:43,473 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2018-03-11 11:14:43,475 Parameters: domain_left_edge          = [-0.00509607 -0.00509607 -0.00509607]
# yt : [INFO     ] 2018-03-11 11:14:43,478 Parameters: domain_right_edge         = [0.00509607 0.00509607 0.00509607]
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     8	         32768	            32
#   1	    92	        208896	            60
#   2	   396	       1200128	           107
# ----------------------------------------------
#    	   496	       1441792
#
#
# t = 0.00000000e+00 = 0.00000000e+00 s = 0.00000000e+00 years
#
# Smallest Cell:
# 	Width: 2.581e-27 Mpc
# 	Width: 2.581e-21 pc
# 	Width: 5.323e-16 AU
# 	Width: 7.963e-03 cm

# %% [markdown]
# ## Projection Plot

# %%
ao.projection_plot(axis='z', field='rho', unit='C/m**3', zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-11 11:11:52,595 Projection completed
# yt : [INFO     ] 2018-03-11 11:11:52,597 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-11 11:11:52,599 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-11 11:11:52,600 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-11 11:11:52,600 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-11 11:11:52,602 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [INFO     ] 2018-03-11 11:11:52,773 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Load New File

# %%
ao = AmrOpal()


ao.load_file(dirname='/home/matthias/Documents/projects/pyOPALTools/amr/tests/plt0000000060/',
             showme=False)
# Out:
# yt : [INFO     ] 2018-03-11 11:25:47,721 Parameters: current_time              = 4.93583e-09
# yt : [INFO     ] 2018-03-11 11:25:47,723 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2018-03-11 11:25:47,725 Parameters: domain_left_edge          = [-0.00683546 -0.00683546 -0.00683546]
# yt : [INFO     ] 2018-03-11 11:25:47,727 Parameters: domain_right_edge         = [0.00683546 0.00683546 0.00683546]
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     8	         32768	            32
# ----------------------------------------------
#    	     8	         32768
#
#
# t = 4.93583000e-09 = 4.93583000e-09 s = 1.56407014e-16 years
#
# Smallest Cell:
# 	Width: 1.385e-26 Mpc
# 	Width: 1.385e-20 pc
# 	Width: 2.856e-15 AU
# 	Width: 4.272e-02 cm

# %% [markdown]
# ## Slice Plot

# %%
ao.slice_plot(normal='z', field='Ex', unit='V/m',
              zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-11 11:15:25,018 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:25,020 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:25,025 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:25,029 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:25,034 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# yt : [WARNING  ] 2018-03-11 11:15:25,082 Plot image for field ('boxlib', 'Ex') has both positive and negative values. Min = -8038.555992, Max = 7928.578433.
# yt : [WARNING  ] 2018-03-11 11:15:25,083 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2018-03-11 11:15:25,310 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# /home/matthias/Documents/projects/yt/build_new/lib/python3.6/site-packages/yt-3.4.1-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1314: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# ...

# %%
ao.slice_plot(normal='z', field='electric_field_y', unit='V/m',
              zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-11 11:15:27,588 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:27,595 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:27,600 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:27,601 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:27,605 Making a fixed resolution buffer of (('gas', 'electric_field_y')) 800 by 800
# yt : [WARNING  ] 2018-03-11 11:15:27,644 Plot image for field ('gas', 'electric_field_y') has both positive and negative values. Min = -8652.649456, Max = 8605.051959.
# yt : [WARNING  ] 2018-03-11 11:15:27,645 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2018-03-11 11:15:27,880 Making a fixed resolution buffer of (('gas', 'electric_field_y')) 800 by 800
# /home/matthias/Documents/projects/yt/build_new/lib/python3.6/site-packages/yt-3.4.1-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1314: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
ao.slice_plot(normal='z', field='electrostatic_potential', unit='V',
              zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-11 11:15:29,858 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:29,861 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:29,867 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:29,869 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:15:29,873 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [INFO     ] 2018-03-11 11:15:30,100 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# /home/matthias/Documents/projects/yt/build_new/lib/python3.6/site-packages/yt-3.4.1-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1314: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Line Plot

# %%
ao.line_plot(axis='x', field='electrostatic_potential', unit='V', figsize=(15, 10), dpi=300)
# Out:
# yt : [INFO     ] 2018-03-11 11:15:40,787 Max Value is 6.14577e+01 at 0.0002136080000000 0.0002136080000000 0.0002136080000000

# %% [markdown]
# ## Particle Plot

# %%
ao.particle_plot('particle_position_x', 'particle_magnetic_field_z', x_unit='cm')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.particle_plot('particle_position_x', 'particle_momentum_x', 'particle_electric_field_x', x_unit='cm',
                 z_unit='V/m')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.particle_plot('particle_position_x', 'particle_electric_field_x', x_unit='cm')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.particle_plot('particle_position_x', 'particle_position_z', 'particle_radius',
                 x_unit='cm', y_unit='cm')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.particle_plot('particle_position_x', 'particle_momentum_x', x_unit='cm')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Overlay Particles onto Fields

# %%
ao.slice_plot(normal='z', field='electrostatic_potential', unit='V',
              zoom=1.0, color='gray', overlay_particles=True)
# Out:
# yt : [INFO     ] 2018-03-11 11:30:34,717 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:30:34,720 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:30:34,724 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:30:34,726 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:30:34,730 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [INFO     ] 2018-03-11 11:30:34,964 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# /home/matthias/Documents/projects/yt/build_new/lib/python3.6/site-packages/yt-3.4.1-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1314: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.slice_plot(normal='z', field='Ex', unit='V/m',
              zoom=1.0, color='gray', overlay_particles=True)
# Out:
# yt : [INFO     ] 2018-03-11 11:31:00,227 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:31:00,229 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:31:00,234 xlim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:31:00,236 ylim = -0.006835 0.006835
# yt : [INFO     ] 2018-03-11 11:31:00,241 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# yt : [WARNING  ] 2018-03-11 11:31:00,283 Plot image for field ('boxlib', 'Ex') has both positive and negative values. Min = -8038.555992, Max = 7928.578433.
# yt : [WARNING  ] 2018-03-11 11:31:00,284 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2018-03-11 11:31:00,589 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# /home/matthias/Documents/projects/yt/build_new/lib/python3.6/site-packages/yt-3.4.1-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1314: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# ...

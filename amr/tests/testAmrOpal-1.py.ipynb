# %% [markdown]
# ## Load Dataset

# %%
from amr import AmrOpal

ao = AmrOpal()


ao.load_file(dirname='/home/matthias/Documents/projects/pyOPALTools/amr/tests/yt-testUnifSphere',
             showme=False)
# Out:
# yt : [INFO     ] 2018-03-02 17:24:19,528 Parameters: current_time              = 0.0
# yt : [INFO     ] 2018-03-02 17:24:19,529 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2018-03-02 17:24:19,529 Parameters: domain_left_edge          = [-0.00509607 -0.00509607 -0.00509607]
# yt : [INFO     ] 2018-03-02 17:24:19,530 Parameters: domain_right_edge         = [0.00509607 0.00509607 0.00509607]
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     8	         32768	            32
#   1	    92	        208896	            60
#   2	   396	       1200128	           107
# ----------------------------------------------
#    	   496	       1441792
#
#
# t = 0.00000000e+00 = 0.00000000e+00 s = 0.00000000e+00 years
#
# Smallest Cell:
# 	Width: 2.581e-27 Mpc
# 	Width: 2.581e-21 pc
# 	Width: 5.323e-16 AU
# 	Width: 7.963e-03 cm

# %% [markdown]
# ## Projection Plot

# %%
ao.projection_plot(axis='z', field='rho', unit='C/m**3',
                   zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-02 17:24:19,991 Projection completed
# yt : [INFO     ] 2018-03-02 17:24:19,992 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:19,992 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:19,994 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:19,994 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:19,996 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [INFO     ] 2018-03-02 17:24:20,520 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Slice Plot

# %%
ao.slice_plot(normal='z', field='Ex', unit='V/m',
              zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-02 17:24:21,459 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:21,460 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:21,462 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:21,463 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:21,466 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# yt : [WARNING  ] 2018-03-02 17:24:21,540 Plot image for field ('boxlib', 'Ex') has both positive and negative values. Min = -1.505514, Max = 1.492373.
# yt : [WARNING  ] 2018-03-02 17:24:21,541 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2018-03-02 17:24:21,748 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.slice_plot(normal='z', field='electric_field_y', unit='V/m',
              zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-02 17:24:22,313 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:22,314 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:22,315 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:22,316 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:22,317 Making a fixed resolution buffer of (('gas', 'electric_field_y')) 800 by 800
# yt : [WARNING  ] 2018-03-02 17:24:22,380 Plot image for field ('gas', 'electric_field_y') has both positive and negative values. Min = -1.497322, Max = 1.494944.
# yt : [WARNING  ] 2018-03-02 17:24:22,381 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2018-03-02 17:24:22,606 Making a fixed resolution buffer of (('gas', 'electric_field_y')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ao.slice_plot(normal='z', field='electrostatic_potential', unit='V',
              zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2018-03-02 17:24:23,273 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:23,274 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:23,276 xlim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:23,277 ylim = -0.005096 0.005096
# yt : [INFO     ] 2018-03-02 17:24:23,279 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [INFO     ] 2018-03-02 17:24:23,536 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Line Plot

# %%
ao.line_plot(axis='x', field='electrostatic_potential', unit='V', figsize=(15, 10), dpi=300)
# Out:
# yt : [INFO     ] 2018-03-02 17:24:59,354 Max Value is 3.20808e-03 at -0.0000398174500000 -0.0000398182500000 0.0000398078500000

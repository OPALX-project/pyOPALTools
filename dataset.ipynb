# %% [markdown]
# # Load an OPAL Dataset

# %%
from visualization.dataset import *
from visualization.plots import *

try:
    dsets = []
    dsets = load_dataset('./tests/testData/', fname='Accelerated.h5') #ftype=FileType.H5')
    dsets += load_dataset('./tests/testData/', fname='Accelerated.stat')
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     Accelerated.h5
#
# Done.
#
# Start loading files ...
#
#     Accelerated.stat
#
# Done.

# %%
from visualization.styles import jupyter_style

jupyter_style()

# %%
plt = plot_profile1D(dsets, 'time', 'rms_x', xsci=True)
    
plt.show()

# %%
plt = plot_phase_space(ds, 'x', 'px', xsci=True, ysci=True)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-150d0a203de1> in <module>()
# ----> 1 plt = plot_phase_space(ds, 'x', 'px', xsci=True, ysci=True)
#       2
#       3 plt.show()
#
# NameError: name 'ds' is not defined

# %% [markdown]
# # Load an OPAL Dataset

# %%
from visualization.dataset import *
from visualization.plots import *

try:
    ds = load_dataset('./tests/testData/', fname='Accelerated.h5') #ftype=FileType.H5')
except Exception as e:
    print ( e )
# Out:
# Available files:
#     Accelerated.h5
#
# Start loading files ...
#
#     Accelerated.h5
#
# Done.

# %%
plt = plot_profile1D(ds, 'TIME', 'ENERGY')
    
plt.show()

# %%
plt = plot_phase_space(ds, 'x', 'px')
    
plt.show()

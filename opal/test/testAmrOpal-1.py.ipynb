# %% [markdown]
# ## Load Dataset

# %%
import opal
from opal.datasets.filetype import FileType

ds = opal.load_dataset('amr/plt0000000380/', ftype=FileType.AMR)
# Out:
# yt : [INFO     ] 2019-03-28 16:02:13,365 Parameters: current_time              = 1.25041e-07
# yt : [INFO     ] 2019-03-28 16:02:13,366 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-03-28 16:02:13,367 Parameters: domain_left_edge          = [-0.0134029 -0.0134029 -0.0134029]
# yt : [INFO     ] 2019-03-28 16:02:13,368 Parameters: domain_right_edge         = [0.0134029 0.0134029 0.0134029]

# %%
print ( ds )
# Out:
# 	AMR dataset.
#
# 	Available fields (41) :
#
# 	    particle_charge
# 	    particle_cpu
# 	    particle_electric_field_x
# 	    particle_electric_field_y
# 	    particle_electric_field_z
# 	    particle_energy_bin
# 	    particle_id
# 	    particle_magnetic_field_x
# 	    particle_magnetic_field_y
# 	    particle_magnetic_field_z
# 	    particle_mass
# 	    particle_momentum_x
# 	    particle_momentum_y
# 	    particle_momentum_z
# 	    particle_position_x
# 	    particle_position_y
# 	    particle_position_z
# 	    particle_timestep
# 	    Ex
# 	    Ey
# 	    Ez
# 	    phi
# 	    rho
# 	    particle_charge
# 	    particle_cpu
# 	    particle_electric_field_x
# 	    particle_electric_field_y
# 	    particle_electric_field_z
# 	    particle_energy_bin
# 	    particle_id
# 	    particle_magnetic_field_x
# 	    particle_magnetic_field_y
# 	    particle_magnetic_field_z
# 	    particle_mass
# 	    particle_momentum_x
# 	    particle_momentum_y
# 	    particle_momentum_z
# 	    particle_position_x
# 	    particle_position_y
# 	    particle_position_z
# 	    particle_timestep
#
# 	Available derived fields (152) :
#
# 	    mesh_id
# 	    particle_charge
# 	    particle_cpu
# 	    particle_electric_field_x
# 	    particle_electric_field_y
# 	    particle_electric_field_z
# 	    particle_energy_bin
# 	    particle_id
# 	    particle_magnetic_field_x
# 	    particle_magnetic_field_y
# 	    particle_magnetic_field_z
# 	    particle_mass
# 	    particle_momentum_x
# 	    particle_momentum_y
# 	    particle_momentum_z
# 	    particle_ones
# 	    particle_position
# 	    particle_position_cylindrical_radius
# 	    particle_position_cylindrical_theta
# 	    particle_position_cylindrical_z
# 	    particle_position_relative
# 	    particle_position_relative_x
# 	    particle_position_relative_y
# 	    particle_position_relative_z
# 	    particle_position_spherical_phi
# 	    particle_position_spherical_radius
# 	    particle_position_spherical_theta
# 	    particle_position_x
# 	    particle_position_y
# 	    particle_position_z
# 	    particle_radius
# 	    particle_spherical_position_phi
# 	    particle_spherical_position_radius
# 	    particle_spherical_position_theta
# 	    particle_timestep
# 	    relative_particle_position
# 	    relative_particle_position_x
# 	    relative_particle_position_y
# 	    relative_particle_position_z
# 	    Ex
# 	    Ey
# 	    Ez
# 	    cell_volume
# 	    dx
# 	    dy
# 	    dz
# 	    path_element_x
# 	    path_element_y
# 	    path_element_z
# 	    phi
# 	    rho
# 	    vertex_x
# 	    vertex_y
# 	    vertex_z
# 	    x
# 	    y
# 	    z
# 	    all_cic
# 	    all_count
# 	    all_density
# 	    all_mass
# 	    opal_cic
# 	    opal_count
# 	    opal_density
# 	    opal_mass
# 	    cell_volume
# 	    charge_density
# 	    dx
# 	    dy
# 	    dz
# 	    electric_field_x
# 	    electric_field_y
# 	    electric_field_z
# 	    electrostatic_potential
# 	    path_element_x
# 	    path_element_y
# 	    path_element_z
# 	    vertex_x
# 	    vertex_y
# 	    vertex_z
# 	    x
# 	    y
# 	    z
# 	    cell_volume
# 	    cylindrical_r
# 	    cylindrical_radius
# 	    cylindrical_theta
# 	    cylindrical_z
# 	    disk_angle
# 	    dx
# 	    dy
# 	    dz
# 	    grid_indices
# 	    grid_level
# 	    height
# 	    ones
# 	    ones_over_dx
# 	    path_element_x
# 	    path_element_y
# 	    path_element_z
# 	    radius
# 	    spherical_phi
# 	    spherical_r
# 	    spherical_radius
# 	    spherical_theta
# 	    vertex_x
# 	    vertex_y
# 	    vertex_z
# 	    virial_radius_fraction
# 	    x
# 	    y
# 	    z
# 	    zeros
# 	    mesh_id
# 	    particle_charge
# 	    particle_cpu
# 	    particle_electric_field_x
# 	    particle_electric_field_y
# 	    particle_electric_field_z
# 	    particle_energy_bin
# 	    particle_id
# 	    particle_magnetic_field_x
# 	    particle_magnetic_field_y
# 	    particle_magnetic_field_z
# 	    particle_mass
# 	    particle_momentum_x
# 	    particle_momentum_y
# 	    particle_momentum_z
# 	    particle_ones
# 	    particle_position
# 	    particle_position_cylindrical_radius
# 	    particle_position_cylindrical_theta
# 	    particle_position_cylindrical_z
# 	    particle_position_relative
# 	    particle_position_relative_x
# 	    particle_position_relative_y
# 	    particle_position_relative_z
# 	    particle_position_spherical_phi
# 	    particle_position_spherical_radius
# 	    particle_position_spherical_theta
# 	    particle_position_x
# 	    particle_position_y
# 	    particle_position_z
# 	    particle_radius
# 	    particle_spherical_position_phi
# 	    particle_spherical_position_radius
# 	    particle_spherical_position_theta
# 	    particle_timestep
# 	    relative_particle_position
# 	    relative_particle_position_x
# 	    relative_particle_position_y
# 	    relative_particle_position_z

# %% [markdown]
# ## Projection Plot

# %%
ds.projection_plot(axis='z', field='rho', unit='C/m**3', zoom=1.0, color='gray', overlay_particles=True)
# Out:
# yt : [INFO     ] 2019-03-28 16:02:13,892 Projection completed
# yt : [INFO     ] 2019-03-28 16:02:13,893 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:13,893 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:13,894 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:13,895 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:13,898 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [INFO     ] 2019-03-28 16:02:14,837 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:15,366 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,380 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,392 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,406 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,421 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,437 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,453 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,468 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:15,482 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.slice_plot(normal='z', field='rho', unit='C/m**3', zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2019-03-28 16:02:16,405 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:16,406 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:16,407 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:16,408 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:16,410 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [INFO     ] 2019-03-28 16:02:16,598 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:16,773 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,778 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,785 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,791 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,797 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,805 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,813 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,821 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:16,830 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Slice Plot

# %%
ds.slice_plot(normal='z', field='Ex', unit='V/m', zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2019-03-28 16:02:17,084 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,084 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,085 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,086 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,087 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:17,138 Plot image for field ('boxlib', 'Ex') has both positive and negative values. Min = -10418.931537, Max = 9863.745790.
# yt : [WARNING  ] 2019-03-28 16:02:17,140 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2019-03-28 16:02:17,320 Making a fixed resolution buffer of (('boxlib', 'Ex')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:17,619 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,626 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,631 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,637 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,643 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,649 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,654 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,660 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:17,667 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.slice_plot(normal='z', field='electric_field_y', unit='V/m', zoom=1.0, color='gray')
# Out:
# yt : [INFO     ] 2019-03-28 16:02:17,990 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,991 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,992 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,992 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:17,994 Making a fixed resolution buffer of (('gas', 'electric_field_y')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:18,043 Plot image for field ('gas', 'electric_field_y') has both positive and negative values. Min = -14955.148049, Max = 14297.597075.
# yt : [WARNING  ] 2019-03-28 16:02:18,044 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2019-03-28 16:02:18,246 Making a fixed resolution buffer of (('gas', 'electric_field_y')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:18,457 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,464 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,471 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,479 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,487 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,494 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,502 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,509 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:18,516 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Line Plot

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
ds.line_plot(axis='y', field='electrostatic_potential', unit='V')

plt.show()
# Out:
# yt : [INFO     ] 2019-03-28 16:02:19,014 Max Value is 1.02893e+02 at 0.0007329500000000 -0.0001047300000000 0.0001046900000000

# %% [markdown]
# ## Particle Plot

# %%
ds.particle_plot('particle_position_x', 'particle_magnetic_field_z', x_unit='cm')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.particle_plot('particle_position_x', 'particle_momentum_x',
                 'particle_electric_field_x', x_unit='cm',
                 z_unit='V/m')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.particle_plot('particle_position_x', 'particle_electric_field_x', x_unit='cm', y_unit='V/m')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Overlay Particles onto Fields

# %%
ds.projection_plot(axis='z', field='electrostatic_potential', unit='V*m',
                   zoom=1.0, color='gray', overlay_particles=True, method='integrate')
# Out:
# yt : [INFO     ] 2019-03-28 16:02:52,691 Projection completed
# yt : [INFO     ] 2019-03-28 16:02:52,692 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:52,693 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:52,696 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:52,697 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:52,704 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [INFO     ] 2019-03-28 16:02:52,872 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:53,390 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,407 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,421 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,438 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,455 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,473 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,489 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,506 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:53,524 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.slice_plot(normal='y', field='electrostatic_potential', unit='V',
              zoom=1.0, color='gray', overlay_particles=True)
# Out:
# yt : [INFO     ] 2019-03-28 16:02:24,803 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:24,804 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:24,805 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:24,805 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:24,807 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [INFO     ] 2019-03-28 16:02:24,988 Making a fixed resolution buffer of (('gas', 'electrostatic_potential')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:25,460 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,465 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,471 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,476 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,484 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,490 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,496 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,501 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:25,507 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.slice_plot(normal='y', field='Ez', unit='V/m',
              zoom=1.0, color='black', overlay_particles=True)
# Out:
# yt : [INFO     ] 2019-03-28 16:02:26,300 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:26,301 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:26,302 xlim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:26,302 ylim = -0.013403 0.013403
# yt : [INFO     ] 2019-03-28 16:02:26,304 Making a fixed resolution buffer of (('boxlib', 'Ez')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:26,357 Plot image for field ('boxlib', 'Ez') has both positive and negative values. Min = -12814.736378, Max = 13982.452375.
# yt : [WARNING  ] 2019-03-28 16:02:26,358 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2019-03-28 16:02:26,535 Making a fixed resolution buffer of (('boxlib', 'Ez')) 800 by 800
# yt : [WARNING  ] 2019-03-28 16:02:27,030 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,037 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,043 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,050 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,056 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,062 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,069 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,075 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2019-03-28 16:02:27,081 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

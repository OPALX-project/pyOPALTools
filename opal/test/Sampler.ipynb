# %% [markdown]
# # Example: Sampler

# %% [markdown]
# ## Load the files

# %%
from opal import load_dataset, filetype

ds = load_dataset('sampler/', fname='turn180_182_samples_0.json')

# %% [markdown]
# ## Set the plotting style

# %%
from opal.visualization.styles import load_style

load_style('jupyter')

# %% [markdown]
# ## Do some plotting ...

# %%
import numpy as np

train0 = np.arange(84).tolist()
train1 = np.arange(168).tolist()
train2 = np.arange(252).tolist()
train3 = np.arange(336).tolist()

plt = ds.plot_training_vs_validation(train0=train0,
                                     train1=train1,
                                     train2=train2,
                                     train3=train3)#,
                                     #nsamples=True)

plt.show()

# %%
import numpy as np

train0 = np.arange(84).tolist()
train3 = np.arange(336).tolist()

plt = ds.plot_auto_correlation(train0)

plt.show()

# %%
plt = ds.plot_auto_correlation(train3)

plt.show()

# %%
plt = ds.plot_auto_correlation(train3, percent=True)

plt.show()

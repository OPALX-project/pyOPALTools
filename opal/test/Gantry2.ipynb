# %% [markdown]
# # Example: Gantry 2
# ## Set the plotting style

# %%
from opal.visualization.styles import jupyter_style

jupyter_style()

# %% [markdown]
# ## Import all plotting functions

# %%
from opal.visualization.plots import *

# %% [markdown]
# ## Load the RingCyclotron.stat file

# %%
from opal.opal import load_dataset

try:
    dsets = load_dataset('./Gantry2/', fname='70MeV_Gantry2_track16.stat')
    #dsets2 = load_dataset('./Gantry2/', fname='70MeV_Gantry2_maps.stat')
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     70MeV_Gantry2_track16.stat ... matches stat file type.
#
# Done.

# %% [markdown]
# ## Envelope Plot

# %%
plt = plot_envelope(ds, lfile='./Gantry2/70MeV_G2.lattice')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-529e303a500d> in <module>()
# ----> 1 plt = plot_envelope(ds, lfile='./Gantry2/70MeV_G2.lattice')
#       2
#       3 plt.show()
#
# ~/Documents/projects/pyOPALTools/opal/visualization/plots.py in plot_envelope(ds, xvar, **kwargs)
#     201
#     202     if lfile:
# --> 203         lattice = LatticeParser()
#     204         lattice.plot(lfile, fig, ax1, ax2)
#     205
#
# ~/Documents/projects/pyOPALTools/utilities/LatticeParser.py in __init__(self)
#      33                                         ''',re.VERBOSE|re.UNICODE)
#      34         self._dictTypes= {
# ---> 35             "monitor": [self.pattern_monitor, 2, 'k-'],
#      36             "collimator":[self.pattern_collimator, 4, 'k-'],
#      37             "dipole": [self.pattern_dipole, 5, 'b-'],
#
# AttributeError: 'LatticeParser' object has no attribute 'pattern_monitor'

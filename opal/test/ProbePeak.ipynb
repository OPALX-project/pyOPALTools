# %% [markdown]
# # Example: Probe Peaks
# ## Set the plotting style

# %%
from opal.visualization.styles import jupyter_style

jupyter_style()

# %% [markdown]
# ## Import all plotting functions

# %%
from opal.visualization.plots import *

# %% [markdown]
# ## Load the files

# %%
from opal import load_dataset

try:
    dsets = load_dataset('./peak/', ftype=FileType.PEAK)
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     RRI2-0065Y08.peaks ... matches peak file type.
#     RRI2.peaks ... matches peak file type.
#
# Done.

# %% [markdown]
# ## Do some plotting ...

# %%
plt = plot_peak_difference(dsets)
    
plt.show()

# %%
from opal import load_dataset

try:
    dsets = load_dataset('./peak/', fname='RRI2.hist')
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     RRI2.hist ... matches probe histogram file type.
#
# Done.

# %%
plt = plot_probe_histogram(ds, grid=True)

plt.show()

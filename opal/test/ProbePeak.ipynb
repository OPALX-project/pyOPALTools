# %% [markdown]
# # Example: Probe Peaks
# ## Set the plotting style

# %%
from opal.visualization.styles import jupyter_style

jupyter_style()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Load the files

# %%
from opal import load_dataset
from opal.datasets.filetype import FileType

dsets = load_dataset('./peak/', ftype=FileType.PEAK)

# %% [markdown]
# ## Do some plotting ...

# %%
plt = dsets[0].plot_peak_difference(dsets[1], grid=True)
    
plt.show()

# %%
from opal import load_dataset

dsets = load_dataset('./peak/', ftype=FileType.HIST)

# %%
plt = dsets[0].plot_probe_histogram(grid=True, scale=True)

dsets[1].plot_probe_histogram( grid=True, scale=True)

plt.show()

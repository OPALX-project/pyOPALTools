# %% [markdown]
# # Example: Probe Peaks
# ## Set the plotting style

# %%
from opal.visualization.styles import jupyter_style

jupyter_style()
# Out:
# import:  jupyter
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Import all plotting functions

# %%
from opal.visualization.plots import *

# %% [markdown]
# ## Load the files

# %%
from opal import load_dataset

try:
    dsets = load_dataset('./peak/', ftype=FileType.PEAK)
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     RRI2-0065Y08.peaks ... matches peak file type.
#     RRI2.peaks ... matches peak file type.
#
# Done.

# %% [markdown]
# ## Do some plotting ...

# %%
plt = plot_peak_difference(dsets, grid=True)
    
plt.show()

# %%
from opal import load_dataset

try:
    dsets = load_dataset('./peak/', ftype=FileType.HIST)
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     RRI2-0065Y08.hist ... matches probe histogram file type.
#     RRI2.hist ... matches probe histogram file type.
#
# Done.

# %%
plt = plot_probe_histogram(dsets[1], grid=True, scale=True)

plot_probe_histogram(dsets[0], grid=True, scale=True)

plt.show()

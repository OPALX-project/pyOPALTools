# %% [markdown]
# # Cyclotron Tests
# ## Set the plotting style

# %%
from opal.visualization.styles import jupyter_style

jupyter_style()
# Out:
# /home/scratch/OPAL/pyOPALTools/pyOPALTools.venv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Import all plotting functions

# %%
from opal.visualization.plots import *

# %% [markdown]
# ## Load the RingCyclotron.stat file

# %%
from opal.opal import load_dataset

try:
    dsets = load_dataset('./../../tests/testData/', ftype=FileType.TRACK_ORBIT)
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     Accelerated-trackOrbit.dat ... matches track orbit file type.
#
# Done.

# %% [markdown]
# ## Turn Separation

# %%
plt = plot_turn_separation(ds,nsteps=720)

plt.show()

# %%
plt = plot_centering(ds)

plt.show()
# Out:
# Centering values [R0,DR,E,F] = [ 3.57264213e+03  1.44297636e+01 -2.02490657e-01 -2.77630462e-02]

# %%
plt = plot_beta_beat(ds)

plt.show()

# %%
plot_energy(ds).show()

# %%
plot_energy_gain(ds).show()

# %% [markdown]
# ## RF Phases

# %%
from opal.opal import load_dataset

try:
    dsets = load_dataset('./../../tests/testData/', fname='Accelerated.out')
    
    ds = dsets[0]
except Exception as e:
    print ( e )
# Out:
# Start loading files ...
#
#     Accelerated.out ... matches OPAL standard output file type.
#
# Done.

# %%
cnames = ['RF3B','RF4A']

plt = plot_RF_phases(ds, cnames)

plt.show()

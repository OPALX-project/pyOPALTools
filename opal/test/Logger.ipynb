# %%
from opal.utilities.logger import opal_logger

# %%
import opal

dsets = opal.load_dataset('./RingCyclotron/', fname='RingCyclotron.stat')

# %%
import opal

dsets = opal.load_dataset('./RingCyclotron/', fname='RingCyclotron.h')
# Out:
# 2019-03-30 14:26:56,790 - opal - ERROR - File './RingCyclotron/RingCyclotron.h' does not exist.

# %%
import opal

dsets = opal.load_dataset('./RingCyclotron/')
# Out:
# 2019-03-30 14:26:56,798 - opal - ERROR - Neither file type 'ftype' nor file name 'fname' specified.
# 2019-03-30 14:26:56,799 - opal - ERROR - No dataset loaded.

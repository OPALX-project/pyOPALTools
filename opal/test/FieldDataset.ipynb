# %% [markdown]
# ***Info:*** OPAL compiled with `-DDBG_SCALARFIELD=ON` writes the charge density, electrostatic potential and electric field to files.

# %%
from opal import load_dataset, filetype
from opal.visualization.styles import load_style

load_style('jupyter')

ds = load_dataset('FieldDataset', fname='test-phi_scalar-000000.dat')

# %%
print (ds)

# %%
plt = ds.plot_projection(field='phi', normal='z')
plt.tight_layout()
plt.show()
plt.close()

# %%
plt = ds.plot_projection(field='ex', normal='z')
plt.tight_layout()
plt.show()
plt.close()

# %%
plt = ds.plot_projection(field='ey', normal='z')
plt.tight_layout()
plt.show()
plt.close()

# %%
plt = ds.plot_projection(field='ez', normal='x')
plt.tight_layout()
plt.show()
plt.close()
